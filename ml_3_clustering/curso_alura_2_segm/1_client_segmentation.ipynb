# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from yellowbrick.cluster import KElbowVisualizer
import seaborn as sns
from datetime import datetime


SEED = 42
np.random.seed(SEED)

df_data = pd.read_csv('../../0_datasets/clustering/client_segmentation.csv', header=0, sep=',')
df_data.head()
# Out:
#    amostra                        id_cliente  \
# 0        0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1        1  8912fc0c3bbf1e2fbf35819e21706718
# 2        2  8912fc0c3bbf1e2fbf35819e21706718
# 3        3  f0ac8e5a239118859b1734e1087cbb1f
# 4        4  6bc8d08963a135220ed6c6d098831f84
#
#                    id_unico_cliente  item_id  cep_cliente   cidade_cliente  \
# 0  861eff4711a542e4b93843c6dd7febb0        1        14409           franca
# 1  9eae34bbd3a474ec5d07949ca7de67c0        1        68030         santarem
# 2  9eae34bbd3a474ec5d07949ca7de67c0        2        68030         santarem
# 3  3c799d181c34d51f6d44bbbc563024db        1        92480  nova santa rita
# 4  23397e992b09769faf5e66f9e171a241        1        25931             mage
#
#   estado_cliente                         id_pedido status_pedido  \
# 0             SP  00e7ee1b050b8499577073aeb2a297a1     delivered
# 1             PA  c1d2b34febe9cd269e378117d6681172     delivered
# ...

# %% [markdown]
# ### Encontrando melhor agrupamento

# %%
def plot_perc(st, dados):
    plt.figure(figsize=(20,8))
    g = sns.countplot(x=st, data=dados, palette="Blues_d", orient='h')
    g.set_ylabel("Contagem", fontsize=17)

    sizes=[]
    for p in g.patches:
        height = p.get_height()
        sizes.append(height)
        g.text(p.get_x() + p.get_width()/1.6,
                height + 200,
                '{:1.2f}%'.format(height / 116581*100),
                ha="center", fontsize=12)
        
    g.set_ylim(0, max(sizes) * 1.1)

plot_perc('estados', df_data['estado_cliente'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 17
#      10         g.text(p.get_x() + p.get_width()/1.6,
#      11                 height + 200,
#      12                 '{:1.2f}%'.format(height / 116581*100),
#      13                 ha="center", fontsize=12)
#      15     g.set_ylim(0, max(sizes) * 1.1)
# ---> 17 plot_perc('estados', df_data['estado_cliente'].value_counts())
#
# Cell In[17], line 3, in plot_perc(st, dados)
#       1 def plot_perc(st, dados):
#       2     plt.figure(figsize=(20,8))
# ----> 3     g = sns.countplot(x=st, data=dados, palette="Blues_d", orient='h')
#       4     g.set_ylabel("Contagem", fontsize=17)
#       6     sizes=[]
#
# ...
